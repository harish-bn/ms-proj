# %%
import pandas as pd
import numpy as np
#from rouge import Rouge
from datasets import load_metric
import evaluate
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
rouge_metric = load_metric('rouge')
# Out:
# WARNING:tensorflow:From D:\anaconda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\Dell\AppData\Local\Temp\ipykernel_27764\1952566898.py:8: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge_metric = load_metric('rouge')
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\datasets\load.py:756: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.18.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# ...

# %% [markdown]
# ### Plot GPT ATS Zero Shot Metrics

# %%
df = pd.read_csv('./output/GPT_ATS_PT_Metrics.csv')
df.rename(columns = {'Unnamed: 0':'GPT ATS Zero Shot Methods', "rouge1":"ROUGE 1", "rouge2":"ROUGE 2","rougeL":"ROUGE L", "rougeLsum": 'ROUGE LSUM'}, inplace = True) 
df.head(20)
# Out:
#        GPT ATS Zero Shot Methods   ROUGE 1   ROUGE 2   ROUGE L  ROUGE LSUM
# 0     gpt4_ats_low_temp_30_words  0.405306  0.110701  0.210759    0.210759
# 1     gpt4_ats_med_temp_30_words  0.372781  0.085926  0.184911    0.184911
# 2    gpt4_ats_high_temp_30_words  0.271859  0.050037  0.132256    0.132256
# 3    gpt35_ats_low_temp_30_words  0.412491  0.109091  0.196078    0.196078
# 4    gpt35_ats_med_temp_30_words  0.393200  0.088823  0.172949    0.172949
# 5   gpt35_ats_high_temp_30_words  0.115964  0.016591  0.057229    0.057229
# 6     gpt4_ats_low_temp_60_words  0.444179  0.112373  0.199403    0.199403
# 7     gpt4_ats_med_temp_60_words  0.447337  0.107820  0.182249    0.182249
# 8    gpt4_ats_high_temp_60_words  0.187683  0.032883  0.089150    0.089150
# 9    gpt35_ats_low_temp_60_words  0.502570  0.149800  0.210166    0.210166
# 10   gpt35_ats_med_temp_60_words  0.477044  0.121076  0.197088    0.197088
# ...

# %% [markdown]
# ### Plot GPT ETS Zero Shot Metrics

# %%
df = pd.read_csv('./output/GPT_ETS_PT_Metrics.csv')
df.rename(columns = {'Unnamed: 0':'GPT ETS Zero Shot Methods', "rouge1":"ROUGE 1", "rouge2":"ROUGE 2","rougeL":"ROUGE L", "rougeLsum": 'ROUGE LSUM'}, inplace = True) 
df.head(20)
# Out:
#        GPT ETS Zero Shot Methods   ROUGE 1   ROUGE 2   ROUGE L  ROUGE LSUM
# 0     gpt4_ets_low_temp_30_words  0.392707  0.134831  0.218794    0.218794
# 1     gpt4_ets_med_temp_30_words  0.384507  0.108604  0.200000    0.200000
# 2    gpt4-ets_high_temp_30_words  0.350903  0.117137  0.189170    0.189170
# 3    gpt35_ets_low_temp_30_words  0.420685  0.149755  0.218029    0.218029
# 4    gpt35_ets_med_temp_30_words  0.384615  0.105042  0.201399    0.201399
# 5   gpt35-ets_high_temp_30_words  0.145773  0.023358  0.074344    0.074344
# 6     gpt4_ets_low_temp_60_words  0.498571  0.157985  0.234420    0.234420
# 7     gpt4_ets_med_temp_60_words  0.491991  0.160367  0.239130    0.239130
# 8    gpt4-ets_high_temp_60_words  0.467218  0.146718  0.217080    0.217080
# 9    gpt35_ets_low_temp_60_words  0.491749  0.157489  0.237624    0.237624
# 10   gpt35_ets_med_temp_60_words  0.479730  0.131905  0.216216    0.216216
# ...

# %% [markdown]
# ### Plot GPT ATS Few Shot Metrics

# %%
df = pd.read_csv('./output/GPT_ATS_FS_Metrics.csv')
df.rename(columns = {'Unnamed: 0':'GPT ATS Few Shot Methods', "rouge1":"ROUGE 1", "rouge2":"ROUGE 2","rougeL":"ROUGE L", "rougeLsum": 'ROUGE LSUM'}, inplace = True) 
  
df.head(20)
# Out:
#                 GPT ATS Few Shot Methods   ROUGE 1   ROUGE 2   ROUGE L  \
# 0     gpt4-abs-5_shots_low_temp_60_words  0.482039  0.148492  0.223638
# 1     gpt4-abs-5_shots_med_temp_60_words  0.474496  0.144893  0.213523
# 2    gpt4-abs-5_shots_high_temp_60_words  0.277907  0.071013  0.134884
# 3    gpt35-abs-5_shots_low_temp_60_words  0.512265  0.185037  0.257844
# 4    gpt35-abs-5_shots_med_temp_60_words  0.520089  0.137430  0.233259
# 5   gpt35-abs-5_shots_high_temp_60_words  0.070828  0.007212  0.033613
# 6     gpt4-abs-3_shots_low_temp_60_words  0.478841  0.157864  0.227246
# 7     gpt4-abs-3_shots_med_temp_60_words  0.493392  0.173098  0.240088
# 8    gpt4-abs-3_shots_high_temp_60_words  0.268508  0.067478  0.119337
# 9    gpt35-abs-3_shots_low_temp_60_words  0.531588  0.184615  0.260672
# 10   gpt35-abs-3_shots_med_temp_60_words  0.496124  0.149667  0.229236
# 11  gpt35-abs-3_shots_high_temp_60_words  0.104963  0.011422  0.044495
# ...

# %% [markdown]
# ### Plot GPT ETS Few Shot Metrics

# %%
df = pd.read_csv('./output/GPT_ETS_FS_Metrics.csv')
df.rename(columns = {'Unnamed: 0':'GPT ETS Few Shot Methods', "rouge1":"ROUGE 1", "rouge2":"ROUGE 2","rougeL":"ROUGE L", "rougeLsum": 'ROUGE LSUM'}, inplace = True) 
df.head(20)
# Out:
#                 GPT ETS Few Shot Methods   ROUGE 1   ROUGE 2   ROUGE L  \
# 0     gpt4-ets-5_shots_low_temp_60_words  0.498015  0.176036  0.245037
# 1     gpt4-ets-5_shots_med_temp_60_words  0.476636  0.157895  0.233645
# 2    gpt4-ets-5_shots_high_temp_60_words  0.491448  0.175799  0.237172
# 3    gpt35-ets-5_shots_low_temp_60_words  0.501699  0.159864  0.238958
# 4    gpt35-ets-5_shots_med_temp_60_words  0.492341  0.132530  0.229759
# 5   gpt35-ets-5_shots_high_temp_60_words  0.472873  0.124643  0.209023
# 6     gpt4-ets-3_shots_low_temp_60_words  0.498856  0.156930  0.232265
# 7     gpt4-ets-3_shots_med_temp_60_words  0.492308  0.158768  0.235503
# 8    gpt4-ets-3_shots_high_temp_60_words  0.440936  0.163934  0.219883
# 9    gpt35-ets-3_shots_low_temp_60_words  0.527072  0.181416  0.251934
# 10   gpt35-ets-3_shots_med_temp_60_words  0.478458  0.132804  0.214286
# 11  gpt35-ets-3_shots_high_temp_60_words  0.097019  0.007022  0.051432
# ...
